# %%
import pandas as pd
import numpy as np
import sklearn

# %%
df = pd.read_csv("unclean_data.csv", encoding="latin1")

# %%
df.head(10)
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
# 5                              Spider-Man 3?ÿ                     392
# 6                                   Tangled?ÿ                     324
# 7                   Avengers: Age of Ultron?ÿ                     635
# 8                   Avengers: Age of Ultron?ÿ                     635
# 9    Harry Potter and the Half-Blood Prince?ÿ                     375
#
#    duration  DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                     10.0                     855
# 1       NaN                    563.0                    1000
# ...

# %%
df.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
df.describe()
# Out:
#        num_critic_for_reviews    duration  DIRECTOR_facebook_likes  \
# count               14.000000   11.000000                11.000000
# mean               506.142857  150.727273              2171.909091
# std                169.069789   21.679903              6580.135720
# min                302.000000  106.000000                10.000000
# 25%                379.250000  141.000000                12.500000
# 50%                448.000000  151.000000                23.000000
# 75%                635.000000  162.500000               479.000000
# max                813.000000  183.000000             22000.000000
#
#        actor_3_facebook_likes  ACTOR_1_facebook_likes         gross  \
# count               14.000000               14.000000  1.400000e+01
# mean              5866.142857            18206.428571  3.335836e+08
# std               8289.592695            13905.214361  1.720674e+08
# min                161.000000              451.000000  7.305868e+07
# ...

# %%
df.columns=df.columns.str.upper()

# %%
df.columns
# Out:
# Index(['MOVIE_TITLE', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'NUM_VOTED_USERS',
#        'CAST_TOTAL_FACEBOOK_LIKES', 'FACENUMBER_IN_POSTER',
#        'NUM_USER_FOR_REVIEWS', 'BUDGET', 'TITLE_YEAR',
#        'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE', 'TITLE_YEAR.1'],
#       dtype='object')

# %%
df = df.rename(columns=({"DURATION":"Time"}))

# %%
df.isnull()
# Out:
#     MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS   Time  DIRECTOR_FACEBOOK_LIKES  \
# 0         False                   False  False                    False
# 1         False                   False   True                    False
# 2         False                   False  False                    False
# 3         False                   False   True                    False
# 4         False                   False  False                     True
# 5         False                   False  False                    False
# 6         False                   False   True                    False
# 7         False                   False  False                    False
# 8         False                   False  False                    False
# 9         False                   False  False                    False
# 10        False                   False  False                     True
# 11        False                   False  False                     True
# ...

# %%
df.isnull().any()
# Out:
# MOVIE_TITLE                  False
# NUM_CRITIC_FOR_REVIEWS       False
# Time                          True
# DIRECTOR_FACEBOOK_LIKES       True
# ACTOR_3_FACEBOOK_LIKES       False
# ACTOR_1_FACEBOOK_LIKES       False
# GROSS                        False
# NUM_VOTED_USERS               True
# CAST_TOTAL_FACEBOOK_LIKES     True
# FACENUMBER_IN_POSTER          True
# NUM_USER_FOR_REVIEWS         False
# BUDGET                       False
# TITLE_YEAR                   False
# ACTOR_2_FACEBOOK_LIKES        True
# IMDB_SCORE                   False
# TITLE_YEAR.1                  True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# MOVIE_TITLE                  0
# NUM_CRITIC_FOR_REVIEWS       0
# Time                         3
# DIRECTOR_FACEBOOK_LIKES      3
# ACTOR_3_FACEBOOK_LIKES       0
# ACTOR_1_FACEBOOK_LIKES       0
# GROSS                        0
# NUM_VOTED_USERS              1
# CAST_TOTAL_FACEBOOK_LIKES    2
# FACENUMBER_IN_POSTER         5
# NUM_USER_FOR_REVIEWS         0
# BUDGET                       0
# TITLE_YEAR                   0
# ACTOR_2_FACEBOOK_LIKES       1
# IMDB_SCORE                   0
# TITLE_YEAR.1                 7
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(22)

# %%
df.head()
# Out:
#                                   MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS   Time  \
# 0                                    Avatar?ÿ                     723  178.0
# 1  Pirates of the Caribbean: At World's End?ÿ                     302    NaN
# 2                                   Spectre?ÿ                     602  148.0
# 3                     The Dark Knight Rises?ÿ                     813    NaN
# 4                               John Carter?ÿ                     462  132.0
#
#    DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  ACTOR_1_FACEBOOK_LIKES  \
# 0                     10.0                     855                    1000
# 1                    563.0                    1000                   40000
# 2                     20.0                     161                   11000
# 3                  22000.0                   23000                   27000
# 4                      NaN                     530                     640
#
# ...

# %%
df0=df.fillna(0)

# %%
df0.head()
# Out:
#                                   MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS   Time  \
# 0                                    Avatar?ÿ                     723  178.0
# 1  Pirates of the Caribbean: At World's End?ÿ                     302    0.0
# 2                                   Spectre?ÿ                     602  148.0
# 3                     The Dark Knight Rises?ÿ                     813    0.0
# 4                               John Carter?ÿ                     462  132.0
#
#    DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  ACTOR_1_FACEBOOK_LIKES  \
# 0                     10.0                     855                    1000
# 1                    563.0                    1000                   40000
# 2                     20.0                     161                   11000
# 3                  22000.0                   23000                   27000
# 4                      0.0                     530                     640
#
# ...

# %%
df["Time"].mean()
# Out:
# np.float64(150.72727272727272)

# %%
dfmean=df.Time.fillna(df['Time'].mean())

# %%
dfmean
# Out:
# 0     178.000000
# 1     150.727273
# 2     148.000000
# 3     150.727273
# 4     132.000000
# 5     156.000000
# 6     150.727273
# 7     141.000000
# 8     141.000000
# 9     153.000000
# 10    183.000000
# 11    169.000000
# 12    106.000000
# 13    151.000000
# Name: Time, dtype: float64

# %%
dfmean.mean(numeric_only=True)
# Out:
# np.float64(150.72727272727272)

# %%
df.mean(numeric_only=True)
# Out:
# NUM_CRITIC_FOR_REVIEWS       5.061429e+02
# Time                         1.507273e+02
# DIRECTOR_FACEBOOK_LIKES      2.171909e+03
# ACTOR_3_FACEBOOK_LIKES       5.866143e+03
# ACTOR_1_FACEBOOK_LIKES       1.820643e+04
# GROSS                        3.335836e+08
# NUM_VOTED_USERS              4.621578e+05
# CAST_TOTAL_FACEBOOK_LIKES    4.477358e+04
# FACENUMBER_IN_POSTER         2.111111e+00
# NUM_USER_FOR_REVIEWS         1.620071e+03
# BUDGET                       2.462643e+08
# TITLE_YEAR                   2.010500e+03
# ACTOR_2_FACEBOOK_LIKES       8.455846e+03
# IMDB_SCORE                   7.171429e+00
# TITLE_YEAR.1                 2.011143e+03
# dtype: float64

# %%
dfdrop=df.dropna()

# %%
dfdrop.shape
# Out:
# (4, 16)

# %%
df.dtypes
# Out:
# MOVIE_TITLE                   object
# NUM_CRITIC_FOR_REVIEWS         int64
# Time                         float64
# DIRECTOR_FACEBOOK_LIKES      float64
# ACTOR_3_FACEBOOK_LIKES         int64
# ACTOR_1_FACEBOOK_LIKES         int64
# GROSS                          int64
# NUM_VOTED_USERS              float64
# CAST_TOTAL_FACEBOOK_LIKES    float64
# FACENUMBER_IN_POSTER         float64
# NUM_USER_FOR_REVIEWS           int64
# BUDGET                         int64
# TITLE_YEAR                     int64
# ACTOR_2_FACEBOOK_LIKES       float64
# IMDB_SCORE                   float64
# TITLE_YEAR.1                 float64
# dtype: object

# %%
from sklearn.ensemble import IsolationForest

# %%
df.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
df=df.fillna(0)

# %%
df.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews         int64
# duration                     float64
# DIRECTOR_facebook_likes      float64
# actor_3_facebook_likes         int64
# ACTOR_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %%
IsolationForest().fit(df[['DDIRECTOR_facebook_likes']]).predict(df[['DIRECTOR_facebook_likeses']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 IsolationForest().fit(df[['DDIRECTOR_facebook_likes']]).predict(df[['DIRECTOR_facebook_likeses']])
#
# File ~/Documents/Che7700/ChE7700HomeWork/homeWork/lib/python3.10/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Documents/Che7700/ChE7700HomeWork/homeWork/lib/python3.10/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...
