# %%
import pandas as pd
import numpy as np
import sklearn

# %%
# Problem #1 Part A

list_a = [3, 4, 6, 10, 39, 87, 12, 54]

A = min(list_a)
print(A)

B = max(list_a)
print(B)

C = sum(list_a)
print(C)
# Out:
# 3
# 87
# 215

# %%
# Problem #1 Part B
list_a.sort()
print(list_a)
print(len(list_a))
list_a[1]
# Out:
# [3, 4, 6, 10, 12, 39, 54, 87]
# 8
# 4

# %%
# Problem #1 Part C

i=0
for i in range (0,len(list_a)):
   print(list_a[i])
# Out:
# 3
# 4
# 6
# 10
# 12
# 39
# 54
# 87
