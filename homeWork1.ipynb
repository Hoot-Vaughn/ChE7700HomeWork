# %%
import pandas as pd
import numpy as np
import sklearn

# %%
# Problem #1 Part A

list_a = [3, 4, 6, 10, 39, 87, 12, 54]

A = min(list_a)
print(A)

B = max(list_a)
print(B)

C = sum(list_a)
print(C)
# Out:
# 3
# 87
# 215
